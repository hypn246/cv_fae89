# %%
from deepface import DeepFace
# Out:
# WARNING:tensorflow:From c:\Users\admin\.conda\envs\env\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from PIL import Image
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
path='what/n2.JPG'
objs = DeepFace.analyze(
  img_path = path, 
  actions = ['age'],
)

# %%
image = cv2.imread(path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.title(f'Prediction: {objs[0]['age']}')
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ay = plt.gca()
ay.get_yaxis().set_visible(False)
plt.imshow(image)
plt.show()
print(objs)
# Out:
# [{'age': 31, 'region': {'x': 654, 'y': 560, 'w': 715, 'h': 715, 'left_eye': (1121, 805), 'right_eye': (818, 1180)}, 'face_confidence': 0.93}]

# %%
C:\Users\admin\.deepface\weights\

# %%
from inference import inference
from PIL import Image
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
pred=inference(image_path='./what/n2.JPG')
print(pred)
# Out:
# ('./what/out.png', 'Age: 20.04', './what/n2.JPG')

# %%
image = cv2.imread(pred[2])
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.title(f'Prediction: {pred[1]}')
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ay = plt.gca()
ay.get_yaxis().set_visible(False)
plt.imshow(image)
plt.show()
